# %%
# %load_ext rpy2.ipython

# %%
# %%R
# Sys.setenv(PATH= paste("/conda/bin" , Sys.getenv("PATH"), sep = ":" ) )
# install.packages('ggmap', repos='http://cran.rstudio.com/')
#
# install.packages('codetools', repos='http://cran.rstudio.com/')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘png’, ‘plyr’, ‘jpeg’, ‘bitops’
#
# trying URL 'http://cran.rstudio.com/src/contrib/png_0.1-9.tar.gz'
# trying URL 'http://cran.rstudio.com/src/contrib/plyr_1.8.9.tar.gz'
# trying URL 'http://cran.rstudio.com/src/contrib/jpeg_0.1-11.tar.gz'
# trying URL 'http://cran.rstudio.com/src/contrib/bitops_1.1-0.tar.gz'
# trying URL 'http://cran.rstudio.com/src/contrib/ggmap_4.0.2.tar.gz'
#
# The downloaded source packages are in
# 	‘/tmp/Rtmpyv1qCO/downloaded_packages’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'http://cran.rstudio.com/src/contrib/codetools_0.2-20.tar.gz'
# Content type 'application/x-gzip' length 38683 bytes (37 KB)
# ...
# downloaded 37 KB
#
#
# The downloaded source packages are in
# 	‘/tmp/Rtmpyv1qCO/downloaded_packages’

# %%
# %%R
#
# # Standard deviations and ecdf;
#
#  # Install and load package ISLR and attach dataset Carseats if not already done;
#
# if (!require(ISLR)) install.packages('ISLR'); library(ISLR);attach(Carseats);
# Out:
# Loading required package: ISLR
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cran.rstudio.com/src/contrib/ISLR_1.4.tar.gz'
# Content type 'application/x-gzip' length 1756715 bytes (1.7 MB)
# ...
# downloaded 1.7 MB
#
#
# The downloaded source packages are in
# 	‘/tmp/Rtmpyv1qCO/downloaded_packages’
# In addition: Warning message:
# In library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE,  :
#   there is no package called ‘ISLR’

# %%
# %%R
#
# # Estimate the fraction of Sales that fall within 1.96 standard deviations of its mean;
#
# # Use the empirical distribution function ecdf()()
#
# ecdf(Sales)(mean(Sales) + 1.96*sd(Sales))-ecdf(Sales)(mean(Sales)-1.96*sd(Sales));
# Out:
# [1] 0.955
